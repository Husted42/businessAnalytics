# %% [markdown]
# *Francisco Pereira [camara@dtu.dk], DTU Management*
#
#
#
# # Advanced Business Analytics

# %% [markdown]
# ## Lecture 1 - Web Data Mining - Part 1: News streams

# %% [markdown]
# A lot of valuable data can be collected from online sources. It can be used to get insights, make predictions, etc. In this notebook, we're going to practice data collection from online sources using API. Particularly, we will collect new data from the New York Times and analyse it using a Sentiment Analysis API.

# %% [markdown]
# **note: We use the NYT and Sentiment APIs because they are both free and straightforward to use. Many others exist that are free but require privacy sensitive data (e.g. credit card) for the registration. We strongly encourage you to try those, which are often more interesting, but be aware of the risks.**

# %% [markdown]
# ### 1. Accessing New York Times (NYT) data

# %% [markdown]
# **! WARNING !**
#
# **In order to make a developer account, you will need to use your email. However, if you do not want to do such registration, you can go through the solutions notebook directly. **

# %% [markdown]
# #### 1.1. Creating developer account
#
# In order to use NYT’s API, you have to create a developer account on the NYT developers website.
#
# 1. Sign in or create a NYT developer account http://developer.nytimes.com.
#
# 2. Create a new app
#      1. Go to your profile->Apps->New App
#      2. App name (required, e.g., *testappxxx12345*)
#      3. For this notebook specifically, you will need to enable the following APIs: Times Wire, Top Stories, Most Popular, and Community.
#
# 3. Once your App has been created, copy your API key. You will need it later on

# %% [markdown]
# #### 1.2. Install request API
# Request is a python library to make access to REST API services, through HTTP calls. You can install request using several options:
# - Anaconda-Navigator: add chanel ```conda-forge```, press "update index...", search for ```requests```, install
# - pip: pip install requests

# %% [markdown]
# #### 1.3. The anatomy of a GET request
# Now that we have the API key, we can playing with our API! We will work with the basic GET requests (and later below, the POST requests). If you understand these well, you are ready for pretty much any API out there. The opportunities are imense! :-)
#
# First, let’s import requests

# %%
import requests

# %% [markdown]
# In practice, a GET request consists of a single http call, where the first part indicates the API server and service (we often call it "url"), and the second part contains the parameters of your call (usually called "params"). The code below exemplifies the idea

# %% [raw]
# url = "<put the URL of the service you want here>"
#
# params = "{dictionary with the parameters that you want to send. Always check with the API documentation!}"
#
# response = requests.request("GET", url, params=params) #this is the actual call you make to the REST API... :-)

# %% [markdown]
# #### 1.4. Example 1: Times Newswire API
# In the first example, we’ll be pulling the 20 most recent news from NYT. We’ll do this by using the API object’s

# %%
import requests

url = "https://api.nytimes.com/svc/news/v3/content/nyt/world.json"


headers = {
    'api-key': "Your Key" #key
    }

response = requests.request("GET", url, params=headers)

# %% [markdown]
# The result should look like a bunch of random news, with the corresponding URL of each news itself. Following the link will often bring you to the news article.

# %% [markdown]
# **we recommend you to inspect manually the "response" object. Among other things, it has a json function, that transforms the returned data into a json dictionary.**

# %%
result=response.json()

# %% [markdown]
# An important field of the response object is the **status_code**. Examples are 200 (request went ok), 400 (you made some mistake), 401 (not authorized, you may have put a wrong API key), 404 (the service was not found at all). For a full list, check https://www.w3.org/Protocols/HTTP/HTRESP.html

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# **inspect the "result" object. You'll it is full of relevant data!**

# %%
result
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2024 The New York Times Company.  All Rights Reserved.',
#  'num_results': 20,
#  'results': [{'slug_name': '07mideast-crisis-hamas-counterproposal',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'A key point of contention is whether a cease-fire would be permanent.',
#    'abstract': '',
#    'uri': 'nyt://article/4da18cfc-809f-5bf9-8879-06d1ee376b3b',
#    'url': 'https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/a-key-point-of-contention-is-whether-a-cease-fire-would-be-permanent',
#    'byline': 'By Adam Rasgon and Aaron Boxerman',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T08:31:40-05:00',
#    'created_date': '2024-02-07T08:15:02-05:00',
#    'published_date': '2024-02-07T08:15:02-05:00',
#    'first_published_date': '2024-02-07T08:15:02-05:00',
#    'material_type_facet': 'Live Blog Post',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': [],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-briefing-carouselz-07-qzcp/07mideast-crisis-briefing-carouselz-07-qzcp-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Salah Al-Din Road in the southern Gaza Strip on Tuesday.',
#      'copyright': 'Mohammed Saber/EPA, via Shutterstock'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-briefing-carouselz-07-qzcp/07mideast-crisis-briefing-carouselz-07-qzcp-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Salah Al-Din Road in the southern Gaza Strip on Tuesday.',
#      'copyright': 'Mohammed Saber/EPA, via Shutterstock'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-briefing-carouselz-07-qzcp/07mideast-crisis-briefing-carouselz-07-qzcp-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Salah Al-Din Road in the southern Gaza Strip on Tuesday.',
#      'copyright': 'Mohammed Saber/EPA, via Shutterstock'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-briefing-carouselz-07-qzcp/07mideast-crisis-briefing-carouselz-07-qzcp-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Salah Al-Din Road in the southern Gaza Strip on Tuesday.',
#      'copyright': 'Mohammed Saber/EPA, via Shutterstock'}]},
#   {'slug_name': '07eu-hungary',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'Hungary and E.U. Lock Horns, This Time Over Foreign-Interference Law',
#    'abstract': 'The European Commission began a disciplinary procedure over recent legislation that focuses on contacts between foreigners and Hungarians.',
#    'uri': 'nyt://article/bb2dcb5a-5d7a-5854-9240-795fe702ef74',
#    'url': 'https://www.nytimes.com/2024/02/07/world/europe/hungary-eu-sovereignty-law.html',
#    'byline': 'By Matina Stevis-Gridneff and Monika Pronczuk',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T07:31:56-05:00',
#    'created_date': '2024-02-07T07:31:56-05:00',
#    'published_date': '2024-02-07T07:31:56-05:00',
#    'first_published_date': '2024-02-07T07:31:56-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Politics and Government',
#     'International Relations',
#     'Law and Legislation'],
#    'org_facet': ['European Commission'],
#    'per_facet': ['Orban, Viktor'],
#    'geo_facet': ['Hungary'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07eu-hungary-wbqj/07eu-hungary-wbqj-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Installing a billboard in Budapest on Tuesday denouncing “gender propaganda.” The line at the bottom reads, “Let’s not dance as Brussels whistles.”',
#      'copyright': 'Attila Kisbenedek/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07eu-hungary-wbqj/07eu-hungary-wbqj-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Installing a billboard in Budapest on Tuesday denouncing “gender propaganda.” The line at the bottom reads, “Let’s not dance as Brussels whistles.”',
#      'copyright': 'Attila Kisbenedek/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07eu-hungary-wbqj/07eu-hungary-wbqj-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Installing a billboard in Budapest on Tuesday denouncing “gender propaganda.” The line at the bottom reads, “Let’s not dance as Brussels whistles.”',
#      'copyright': 'Attila Kisbenedek/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07eu-hungary-wbqj/07eu-hungary-wbqj-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Installing a billboard in Budapest on Tuesday denouncing “gender propaganda.” The line at the bottom reads, “Let’s not dance as Brussels whistles.”',
#      'copyright': 'Attila Kisbenedek/Agence France-Presse — Getty Images'}]},
#   {'slug_name': '07mideast-crisis-france-ceremony',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Macron condemns ‘largest antisemitic massacre of our century’ at an Oct. 7 tribute to French citizens who died in the assault.',
#    'abstract': '',
#    'uri': 'nyt://article/259108ae-0a3f-5fd4-bf50-9257995e0b3f',
#    'url': 'https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/macron-condemns-largest-antisemitic-massacre-of-our-century-at-an-oct-7-tribute-to-french-citizens-who-died-in-the-assault',
#    'byline': 'By Aurelien Breeden',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T07:29:36-05:00',
#    'created_date': '2024-02-07T07:29:36-05:00',
#    'published_date': '2024-02-07T07:29:36-05:00',
#    'first_published_date': '2024-02-07T07:29:36-05:00',
#    'material_type_facet': 'Live Blog Post',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': [],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-france-ceremony-kmjf/07mideast-crisis-france-ceremony-kmjf-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Emmanuel Macron of France at a ceremony for the victims of the Oct. 7 attacks in Paris on Wednesday. Members of the French Republican Guard hold photos of the victims.',
#      'copyright': 'Gonzalo Fuentes/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-france-ceremony-kmjf/07mideast-crisis-france-ceremony-kmjf-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Emmanuel Macron of France at a ceremony for the victims of the Oct. 7 attacks in Paris on Wednesday. Members of the French Republican Guard hold photos of the victims.',
#      'copyright': 'Gonzalo Fuentes/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-france-ceremony-kmjf/07mideast-crisis-france-ceremony-kmjf-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Emmanuel Macron of France at a ceremony for the victims of the Oct. 7 attacks in Paris on Wednesday. Members of the French Republican Guard hold photos of the victims.',
#      'copyright': 'Gonzalo Fuentes/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-france-ceremony-kmjf/07mideast-crisis-france-ceremony-kmjf-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Emmanuel Macron of France at a ceremony for the victims of the Oct. 7 attacks in Paris on Wednesday. Members of the French Republican Guard hold photos of the victims.',
#      'copyright': 'Gonzalo Fuentes/Reuters'}]},
#   {'slug_name': '07pakistan-attack',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Election Office Blasts in Pakistan Kill at Least 22 a Day Before Vote',
#    'abstract': 'Attacks against activities linked to the national elections, including the targeting of candidates, have surged during campaign season.',
#    'uri': 'nyt://article/d69ecaeb-8e62-52f4-a1bd-0145e0ab29c3',
#    'url': 'https://www.nytimes.com/2024/02/07/world/asia/pakistan-elections-attacks.html',
#    'byline': 'By Zia ur-Rehman',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T07:18:20-05:00',
#    'created_date': '2024-02-07T07:18:20-05:00',
#    'published_date': '2024-02-07T07:18:20-05:00',
#    'first_published_date': '2024-02-07T07:18:20-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Terrorism', 'Elections'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': ['Pakistan'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07pakistan-attack-kljg/07pakistan-attack-kljg-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The site of a blast outside the office of an independent candidate in Balochistan Province, Pakistan, on Wednesday.',
#      'copyright': 'Banaras Khan/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07pakistan-attack-kljg/07pakistan-attack-kljg-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The site of a blast outside the office of an independent candidate in Balochistan Province, Pakistan, on Wednesday.',
#      'copyright': 'Banaras Khan/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07pakistan-attack-kljg/07pakistan-attack-kljg-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The site of a blast outside the office of an independent candidate in Balochistan Province, Pakistan, on Wednesday.',
#      'copyright': 'Banaras Khan/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07pakistan-attack-kljg/07pakistan-attack-kljg-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The site of a blast outside the office of an independent candidate in Balochistan Province, Pakistan, on Wednesday.',
#      'copyright': 'Banaras Khan/Agence France-Presse — Getty Images'}]},
#   {'slug_name': '07mideast-crisis-blinken',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Blinken meets with Netanyahu as he tries to further cease-fire negotiations.',
#    'abstract': '',
#    'uri': 'nyt://article/36a4f526-add3-5de4-b299-03c83176b863',
#    'url': 'https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/blinken-meets-with-netanyahu-as-he-tries-to-further-cease-fire-negotiations',
#    'byline': 'By Zolan Kanno-Youngs',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T06:57:53-05:00',
#    'created_date': '2024-02-07T06:47:38-05:00',
#    'published_date': '2024-02-07T06:47:38-05:00',
#    'first_published_date': '2024-02-07T06:47:38-05:00',
#    'material_type_facet': 'Live Blog Post',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': [],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-blinken/07mideast-crisis-briefing-carouselz-04-qzcp-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Antony J. Blinken, the U.S. secretary of state, arriving in Israel on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-blinken/07mideast-crisis-briefing-carouselz-04-qzcp-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Antony J. Blinken, the U.S. secretary of state, arriving in Israel on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-blinken/07mideast-crisis-briefing-carouselz-04-qzcp-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Antony J. Blinken, the U.S. secretary of state, arriving in Israel on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07mideast-crisis-blinken/07mideast-crisis-briefing-carouselz-04-qzcp-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Antony J. Blinken, the U.S. secretary of state, arriving in Israel on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'}]},
#   {'slug_name': '07sweden-nordstream',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'Sweden Closes Investigation Into Nord Stream Pipeline Blasts',
#    'abstract': 'The natural-gas connection was attacked in September 2022, seven months after Russia’s invasion of Ukraine, prompting rampant speculation about who was to blame.',
#    'uri': 'nyt://article/eed086a1-2e48-5e76-841d-458201aa1440',
#    'url': 'https://www.nytimes.com/2024/02/07/world/europe/sweden-nord-stream-pipeline.html',
#    'byline': 'By Rebecca R. Ruiz',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T05:52:33-05:00',
#    'created_date': '2024-02-07T05:52:33-05:00',
#    'published_date': '2024-02-07T05:52:33-05:00',
#    'first_published_date': '2024-02-07T05:52:33-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['International Relations', 'Natural Gas', 'Pipelines'],
#    'org_facet': ['Nord Stream AG'],
#    'per_facet': [],
#    'geo_facet': ['Baltic Sea', 'Sweden', 'Western Europe'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07sweden-nordstream-tqlm/07sweden-nordstream-tqlm-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A photo released by the Danish military in September 2022 showing gas bubbles from the Nord Stream 2 leak reaching the surface of the Baltic Sea, near the Danish island of Bornholm.',
#      'copyright': 'Agence France-Presse, via Danish Defence/Afp Via Getty Ima'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07sweden-nordstream-tqlm/07sweden-nordstream-tqlm-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A photo released by the Danish military in September 2022 showing gas bubbles from the Nord Stream 2 leak reaching the surface of the Baltic Sea, near the Danish island of Bornholm.',
#      'copyright': 'Agence France-Presse, via Danish Defence/Afp Via Getty Ima'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07sweden-nordstream-tqlm/07sweden-nordstream-tqlm-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A photo released by the Danish military in September 2022 showing gas bubbles from the Nord Stream 2 leak reaching the surface of the Baltic Sea, near the Danish island of Bornholm.',
#      'copyright': 'Agence France-Presse, via Danish Defence/Afp Via Getty Ima'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07sweden-nordstream-tqlm/07sweden-nordstream-tqlm-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A photo released by the Danish military in September 2022 showing gas bubbles from the Nord Stream 2 leak reaching the surface of the Baltic Sea, near the Danish island of Bornholm.',
#      'copyright': 'Agence France-Presse, via Danish Defence/Afp Via Getty Ima'}]},
#   {'slug_name': '07ecuador-violence',
#    'section': 'World',
#    'subsection': 'Americas',
#    'title': 'Terrorized by Gangs, Ecuador Embraces the Hard-Line ‘Noboa Way’',
#    'abstract': 'President Daniel Noboa’s new war on gangs has widespread support in a nation overwhelmed by violence. But experts warn it could endanger civil liberties.',
#    'uri': 'nyt://article/308597f7-326c-5230-b890-c68fa944053c',
#    'url': 'https://www.nytimes.com/2024/02/07/world/americas/ecuador-gang-violence-noboa.html',
#    'byline': 'By Annie Correal and Federico Rios',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T05:39:18-05:00',
#    'created_date': '2024-02-07T05:39:18-05:00',
#    'published_date': '2024-02-07T05:39:18-05:00',
#    'first_published_date': '2024-02-07T05:39:18-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['vis-photo',
#     'Gangs',
#     'Drug Abuse and Traffic',
#     'Human Rights and Human Rights Violations',
#     'Civil Rights and Liberties',
#     'Murders, Attempted Murders and Homicides',
#     'Drug Cartels',
#     'Search and Seizure',
#     'Prisons and Prisoners'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/world/07-ecuador-violence-top-promo/00ecuador-violence-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Soldiers during a raid last month in Guayaquil, Ecuador.',
#      'copyright': 'Federico Rios for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/world/07-ecuador-violence-top-promo/00ecuador-violence-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Soldiers during a raid last month in Guayaquil, Ecuador.',
#      'copyright': 'Federico Rios for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/world/07-ecuador-violence-top-promo/00ecuador-violence-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Soldiers during a raid last month in Guayaquil, Ecuador.',
#      'copyright': 'Federico Rios for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/world/07-ecuador-violence-top-promo/00ecuador-violence-articleInline.jpg',
#      'format': 'Normal',
#      'height': 126,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Soldiers during a raid last month in Guayaquil, Ecuador.',
#      'copyright': 'Federico Rios for The New York Times'}]},
#   {'slug_name': '07pakistan-punjab',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'It Was Once Pakistan’s Military Stronghold. Now Even It Has Had Enough.',
#    'abstract': 'The mounting frustration with the military establishment is a stark shift in Punjab, the country’s most populous and politically important province.',
#    'uri': 'nyt://article/9fa49dd9-dee3-5190-95e3-58325d6e3775',
#    'url': 'https://www.nytimes.com/2024/02/07/world/asia/pakistan-election.html',
#    'byline': 'By Christina Goldbaum',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T06:58:58-05:00',
#    'created_date': '2024-02-07T05:24:48-05:00',
#    'published_date': '2024-02-07T05:24:48-05:00',
#    'first_published_date': '2024-02-07T05:24:48-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Politics and Government',
#     'Elections',
#     'Defense and Military Forces'],
#    'org_facet': ['Pakistan Tehreek-e-Insaf'],
#    'per_facet': ['Khan, Imran'],
#    'geo_facet': ['Punjab (Pakistan)'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/00pakistan-add3-lkfb/00pakistan-add3-lkfb-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jhelum, a small city in Punjab, Pakistan’s most affluent and populous province. The country heads to the polls on Thursday. ',
#      'copyright': 'Saiyna Bashir for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/00pakistan-add3-lkfb/00pakistan-add3-lkfb-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jhelum, a small city in Punjab, Pakistan’s most affluent and populous province. The country heads to the polls on Thursday. ',
#      'copyright': 'Saiyna Bashir for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/00pakistan-add3-lkfb/00pakistan-add3-lkfb-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jhelum, a small city in Punjab, Pakistan’s most affluent and populous province. The country heads to the polls on Thursday. ',
#      'copyright': 'Saiyna Bashir for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/00pakistan-add3-lkfb/00pakistan-add3-lkfb-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jhelum, a small city in Punjab, Pakistan’s most affluent and populous province. The country heads to the polls on Thursday. ',
#      'copyright': 'Saiyna Bashir for The New York Times'}]},
#   {'slug_name': '07ukraine-strikes',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'Russian Strikes Hit Ukrainian Cities at a Tense Time for Kyiv',
#    'abstract': 'The attacks killed at least five people, officials said, as Ukraine raises pleas for more American aid and President Volodymyr Zelensky considers changes in his administration.',
#    'uri': 'nyt://article/5790f3d5-d08e-538f-9dbd-e47915c7cced',
#    'url': 'https://www.nytimes.com/2024/02/07/world/europe/russia-ukraine-war-attack.html',
#    'byline': 'By Marc Santora and Andrew E. Kramer',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T06:18:05-05:00',
#    'created_date': '2024-02-07T04:05:42-05:00',
#    'published_date': '2024-02-07T04:05:42-05:00',
#    'first_published_date': '2024-02-07T04:05:42-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Defense and Military Forces',
#     'Russian Invasion of Ukraine (2022)'],
#    'org_facet': [],
#    'per_facet': ['Zelensky, Volodymyr'],
#    'geo_facet': ['Ukraine'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ukraine-strikes-kmlj/07ukraine-strikes-kmlj-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Ukrainian rescuers and medical workers outside a residential building that was damaged in a missile strike in Kyiv on Wednesday.',
#      'copyright': 'Sergei Supinsky/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ukraine-strikes-kmlj/07ukraine-strikes-kmlj-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Ukrainian rescuers and medical workers outside a residential building that was damaged in a missile strike in Kyiv on Wednesday.',
#      'copyright': 'Sergei Supinsky/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ukraine-strikes-kmlj/07ukraine-strikes-kmlj-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Ukrainian rescuers and medical workers outside a residential building that was damaged in a missile strike in Kyiv on Wednesday.',
#      'copyright': 'Sergei Supinsky/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ukraine-strikes-kmlj/07ukraine-strikes-kmlj-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Ukrainian rescuers and medical workers outside a residential building that was damaged in a missile strike in Kyiv on Wednesday.',
#      'copyright': 'Sergei Supinsky/Agence France-Presse — Getty Images'}]},
#   {'slug_name': '07italy-meloni',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'Giorgia Meloni Solidifies Her Credentials in Europe',
#    'abstract': 'The Italian prime minister helped persuade the Hungarian leader, Viktor Orban, to go along with a landmark fund for Ukraine. It was a big moment for Europe. And for her.',
#    'uri': 'nyt://article/3def1943-0056-5695-aaad-9a42e3b1cade',
#    'url': 'https://www.nytimes.com/2024/02/07/world/europe/italy-meloni-orban-ukraine-funding.html',
#    'byline': 'By Jason Horowitz',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T03:36:10-05:00',
#    'created_date': '2024-02-07T00:01:29-05:00',
#    'published_date': '2024-02-07T00:01:29-05:00',
#    'first_published_date': '2024-02-07T00:01:29-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Politics and Government',
#     'International Relations',
#     'Right-Wing Extremism and Alt-Right',
#     'Fringe Groups and Movements',
#     'Russian Invasion of Ukraine (2022)',
#     'Elections'],
#    'org_facet': ['Alternative for Germany',
#     'Brothers of Italy (Italian Political Party)',
#     'European Commission',
#     'European Parliament',
#     "European People's Party",
#     'European Union',
#     'Law and Justice (Poland)',
#     'Vox (Spanish Political Party)'],
#    'per_facet': ['Berlusconi, Silvio',
#     'Le Pen, Marine',
#     'Macron, Emmanuel (1977- )',
#     'Meloni, Giorgia (1977- )',
#     'Putin, Vladimir V',
#     'Salvini, Matteo',
#     'von der Leyen, Ursula',
#     'Wilders, Geert'],
#    'geo_facet': ['Brussels (Belgium)', 'Europe', 'Italy'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06italy-meloni-1-gtcz/06italy-meloni-1-gtcz-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prime Minister Giorgia Meloni of Italy in Brussels last year.',
#      'copyright': 'Kenzo Tribouillard/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06italy-meloni-1-gtcz/06italy-meloni-1-gtcz-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prime Minister Giorgia Meloni of Italy in Brussels last year.',
#      'copyright': 'Kenzo Tribouillard/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06italy-meloni-1-gtcz/06italy-meloni-1-gtcz-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prime Minister Giorgia Meloni of Italy in Brussels last year.',
#      'copyright': 'Kenzo Tribouillard/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06italy-meloni-1-gtcz/06italy-meloni-1-gtcz-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prime Minister Giorgia Meloni of Italy in Brussels last year.',
#      'copyright': 'Kenzo Tribouillard/Agence France-Presse — Getty Images'}]},
#   {'slug_name': '07sandals-dispatch',
#    'section': 'World',
#    'subsection': 'Africa',
#    'title': 'Playing Soccer in Abidjan? Get Yourself a Pair of Lêkê.',
#    'abstract': 'In Ivory Coast, where a major tournament has drawn the continent’s best teams, a plastic sandal is the preferred gear for pickup games and almost everything else.',
#    'uri': 'nyt://article/34744179-5e40-531e-b08a-e44bfc077798',
#    'url': 'https://www.nytimes.com/2024/02/07/world/africa/ivory-coast-leke-africa-cup-of-nations.html',
#    'byline': 'By Elian Peltier and Joao Silva',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T08:14:01-05:00',
#    'created_date': '2024-02-07T00:01:27-05:00',
#    'published_date': '2024-02-07T00:01:27-05:00',
#    'first_published_date': '2024-02-07T00:01:27-05:00',
#    'material_type_facet': 'News',
#    'kicker': 'Ivory Coast dispatch',
#    'subheadline': '',
#    'des_facet': ['vis-photo',
#     'Soccer',
#     'Fashion and Apparel',
#     'African Cup of Nations (Soccer)'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': ['Abidjan (Ivory Coast)'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/04/multimedia/04sandals-diapatch-promo/04sandals-diapatch-01-jmqf-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Joao Silva/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/04/multimedia/04sandals-diapatch-promo/04sandals-diapatch-01-jmqf-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Joao Silva/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/04/multimedia/04sandals-diapatch-promo/04sandals-diapatch-01-jmqf-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Joao Silva/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/04/multimedia/04sandals-diapatch-promo/04sandals-diapatch-01-jmqf-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Joao Silva/The New York Times'}]},
#   {'slug_name': '07mideast-iraq',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Iraq Hosts Both U.S. and Iranian-Backed Forces. It’s Getting Tense.',
#    'abstract': 'As Iranian-backed groups and American forces, both of which have bases in Iraq, lock horns around the Mideast, things are becoming uncomfortable for the Iraqi government.',
#    'uri': 'nyt://article/45e9484e-71ce-5412-bf20-5d3509a8c52e',
#    'url': 'https://www.nytimes.com/2024/02/07/world/middleeast/iraq-iran-us-strikes.html',
#    'byline': 'By Alissa J. Rubin',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T00:01:22-05:00',
#    'created_date': '2024-02-07T00:01:22-05:00',
#    'published_date': '2024-02-07T00:01:22-05:00',
#    'first_published_date': '2024-02-07T00:01:22-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['International Relations',
#     'Israel-Gaza War (2023- )',
#     'United States Defense and Military Forces'],
#    'org_facet': [],
#    'per_facet': ['Sudani, Mohammed Shia al-'],
#    'geo_facet': ['Iraq', 'United States', 'Iran'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/05/multimedia/05mideast-iraq-lhgj/05mideast-iraq-lhgj-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A funeral in Iraq on Sunday for fighters killed in U.S. airstrikes.',
#      'copyright': 'Anmar Khalil/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/02/05/multimedia/05mideast-iraq-lhgj/05mideast-iraq-lhgj-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A funeral in Iraq on Sunday for fighters killed in U.S. airstrikes.',
#      'copyright': 'Anmar Khalil/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/02/05/multimedia/05mideast-iraq-lhgj/05mideast-iraq-lhgj-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A funeral in Iraq on Sunday for fighters killed in U.S. airstrikes.',
#      'copyright': 'Anmar Khalil/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/02/05/multimedia/05mideast-iraq-lhgj/05mideast-iraq-lhgj-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A funeral in Iraq on Sunday for fighters killed in U.S. airstrikes.',
#      'copyright': 'Anmar Khalil/Associated Press'}]},
#   {'slug_name': '06mideast-ledeall',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Hamas Gives ‘Positive’ Reply to Gaza Truce Plan, but Odds Remain Murky',
#    'abstract': 'U.S. and Qatari leaders hinted at progress in talks for a truce and the release of hostages, but it remains unclear how Israel, determined to crush Hamas, will respond to the group’s counteroffer.',
#    'uri': 'nyt://article/fccf4a32-7eae-5878-8f3f-4bde29667770',
#    'url': 'https://www.nytimes.com/2024/02/06/world/middleeast/hamas-israel-truce-hostage-negotiations.html',
#    'byline': 'By Zolan Kanno-Youngs, Adam Rasgon and Michael Levenson',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-06T19:17:38-05:00',
#    'created_date': '2024-02-06T19:00:45-05:00',
#    'published_date': '2024-02-06T19:00:45-05:00',
#    'first_published_date': '2024-02-06T19:00:45-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Israel-Gaza War (2023- )',
#     'Palestinians',
#     'Kidnapping and Hostages',
#     'Refugees and Displaced Persons',
#     'Deaths (Fatalities)',
#     'Peace Process'],
#    'org_facet': ['State Department', 'Hamas', 'Mossad', 'Houthis'],
#    'per_facet': ['Blinken, Antony J',
#     'Thani, Tamim bin Hamad al-',
#     'Sisi, Abdel Fattah el-',
#     'Gallant, Yoav',
#     'Biden, Joseph R Jr'],
#    'geo_facet': ['Doha (Qatar)', 'Cairo (Egypt)', 'Gaza Strip'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-ledeall-thpk/06mideast-ledeall-thpk-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An Israeli strike on Rafah, in the southern Gaza Strip, on Tuesday.',
#      'copyright': 'Mahmud Hams/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-ledeall-thpk/06mideast-ledeall-thpk-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An Israeli strike on Rafah, in the southern Gaza Strip, on Tuesday.',
#      'copyright': 'Mahmud Hams/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-ledeall-thpk/06mideast-ledeall-thpk-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An Israeli strike on Rafah, in the southern Gaza Strip, on Tuesday.',
#      'copyright': 'Mahmud Hams/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-ledeall-thpk/06mideast-ledeall-thpk-articleInline.jpg',
#      'format': 'Normal',
#      'height': 125,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An Israeli strike on Rafah, in the southern Gaza Strip, on Tuesday.',
#      'copyright': 'Mahmud Hams/Agence France-Presse — Getty Images'}]},
#   {'slug_name': '06mideast-crisis-biden-deal',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Biden criticizes Republicans for blocking an immigration bill containing aid for Israel and Gaza.',
#    'abstract': 'Senators from both parties shaped the legislation, which links a crackdown on unlawful migration to delivering emergency aid to war-torn areas overseas.',
#    'uri': 'nyt://article/8e40dd95-ce5b-5c6b-aa4d-6e381ba0defc',
#    'url': 'https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/biden-israel-aid-bill',
#    'byline': 'By Erica L. Green',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T08:19:27-05:00',
#    'created_date': '2024-02-06T17:45:34-05:00',
#    'published_date': '2024-02-06T17:45:34-05:00',
#    'first_published_date': '2024-02-06T17:45:34-05:00',
#    'material_type_facet': 'Live Blog Post',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Israel-Gaza War (2023- )',
#     'Palestinians',
#     'Illegal Immigration',
#     'Humanitarian Aid'],
#    'org_facet': ['Hamas'],
#    'per_facet': ['Biden, Joseph R Jr'],
#    'geo_facet': ['Israel', 'Gaza Strip', 'Ukraine'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-biden-deal-whtz/06mideast-crisis-biden-deal-whtz-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Biden speaking from the State Dining Room at the White House on Tuesday.',
#      'copyright': 'Michael A. McCoy for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-biden-deal-whtz/06mideast-crisis-biden-deal-whtz-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Biden speaking from the State Dining Room at the White House on Tuesday.',
#      'copyright': 'Michael A. McCoy for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-biden-deal-whtz/06mideast-crisis-biden-deal-whtz-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Biden speaking from the State Dining Room at the White House on Tuesday.',
#      'copyright': 'Michael A. McCoy for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-biden-deal-whtz/06mideast-crisis-biden-deal-whtz-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Biden speaking from the State Dining Room at the White House on Tuesday.',
#      'copyright': 'Michael A. McCoy for The New York Times'}]},
#   {'slug_name': '06vid-blinken-negotiations',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Blinken Says ‘Agreement Is Possible’ With Hamas on a Hostage Deal',
#    'abstract': 'Secretary of State Antony J. Blinken cautioned that there was still “a lot of work to be done,” as the United States and its allies prepare to review Hamas’s response to their cease-fire proposal.',
#    'uri': 'nyt://video/b750dc05-c2c1-5c8e-9838-75b04b2e33a8',
#    'url': 'https://www.nytimes.com/video/world/middleeast/100000009300985/blinken-israel-hamas-hostages.html',
#    'byline': 'By The New York Times',
#    'item_type': 'Video',
#    'source': 'New York Times',
#    'updated_date': '2024-02-06T17:26:45-05:00',
#    'created_date': '2024-02-06T17:26:45-05:00',
#    'published_date': '2024-02-06T17:26:45-05:00',
#    'first_published_date': '2024-02-06T17:26:45-05:00',
#    'material_type_facet': 'Video',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Israel-Gaza War (2023- )',
#     'Kidnapping and Hostages',
#     'United States International Relations'],
#    'org_facet': ['Hamas'],
#    'per_facet': ['Blinken, Antony J'],
#    'geo_facet': ['Israel'],
#    'related_urls': [{'suggested_link_text': 'Blinken says a deal is achievable, but there is ‘a lot of work to be done.’',
#      'url': 'https://www.nytimes.com/live/2024/02/06/world/israel-hamas-war-gaza-news/the-reply-includes-some-comments-but-in-general-it-is-positive-the-qatari-prime-minister-says'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-hostage-negotiations-02/06mideast-crisis-briefing-promo-240pm-zgvm-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Secretary of State Antony J. Blinken and the prime minister of Qatar, Sheikh Mohammed bin Abdulrahman bin Jassim al-Thani, in Doha on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-hostage-negotiations-02/06mideast-crisis-briefing-promo-240pm-zgvm-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Secretary of State Antony J. Blinken and the prime minister of Qatar, Sheikh Mohammed bin Abdulrahman bin Jassim al-Thani, in Doha on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-hostage-negotiations-02/06mideast-crisis-briefing-promo-240pm-zgvm-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Secretary of State Antony J. Blinken and the prime minister of Qatar, Sheikh Mohammed bin Abdulrahman bin Jassim al-Thani, in Doha on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-hostage-negotiations-02/06mideast-crisis-briefing-promo-240pm-zgvm-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Secretary of State Antony J. Blinken and the prime minister of Qatar, Sheikh Mohammed bin Abdulrahman bin Jassim al-Thani, in Doha on Tuesday.',
#      'copyright': 'Pool photo by Mark Schiefelbein'}]},
#   {'slug_name': '07ambriefing-asia-web',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Wednesday Briefing: A Legal Blow to Trump',
#    'abstract': 'Plus, a Korean food renaissance in New York.',
#    'uri': 'nyt://article/6cdef8e8-c9d0-508d-9e2e-b2fa688f5d6a',
#    'url': 'https://www.nytimes.com/2024/02/06/world/asia/trump-case-israel-hostages-charles-asia.html',
#    'byline': 'By Amelia Nierenberg',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-06T16:00:36-05:00',
#    'created_date': '2024-02-06T16:00:36-05:00',
#    'published_date': '2024-02-06T16:00:36-05:00',
#    'first_published_date': '2024-02-06T16:00:36-05:00',
#    'material_type_facet': 'briefing',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': [],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': ['Far East, South and Southeast Asia and Pacific Areas'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ambriefing-asia-nl-ckzv-promo/07ambriefing-asia-nl-ckzv-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Former President Donald Trump speaks to members of the media while appearing at his civil fraud trial in New York State Supreme Court.',
#      'copyright': 'Dave Sanders for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ambriefing-asia-nl-ckzv-promo/07ambriefing-asia-nl-ckzv-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Former President Donald Trump speaks to members of the media while appearing at his civil fraud trial in New York State Supreme Court.',
#      'copyright': 'Dave Sanders for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ambriefing-asia-nl-ckzv-promo/07ambriefing-asia-nl-ckzv-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Former President Donald Trump speaks to members of the media while appearing at his civil fraud trial in New York State Supreme Court.',
#      'copyright': 'Dave Sanders for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/07ambriefing-asia-nl-ckzv-promo/07ambriefing-asia-nl-ckzv-articleInline.jpg',
#      'format': 'Normal',
#      'height': 152,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Former President Donald Trump speaks to members of the media while appearing at his civil fraud trial in New York State Supreme Court.',
#      'copyright': 'Dave Sanders for The New York Times'}]},
#   {'slug_name': '06mideast-crisis-argentina-embassy',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Arriving in Israel, Argentina’s new president promises to move his country’s embassy to Jerusalem.',
#    'abstract': '',
#    'uri': 'nyt://article/d6d18cf1-b70f-56ed-bfc8-4d60b7d9e1de',
#    'url': 'https://www.nytimes.com/live/2024/02/06/world/israel-hamas-war-gaza-news/arriving-in-israel-argentinas-new-president-promises-to-move-his-countrys-embassy-to-jerusalem',
#    'byline': 'By Jack Nicas and Lucía Cholakian Herrera',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-06T15:46:18-05:00',
#    'created_date': '2024-02-06T15:46:18-05:00',
#    'published_date': '2024-02-06T15:46:18-05:00',
#    'first_published_date': '2024-02-06T15:46:18-05:00',
#    'material_type_facet': 'Live Blog Post',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': [],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-argentina-embassy-lmhq/06mideast-crisis-argentina-embassy-lmhq-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Javier Milei of Argentina at the Western Wall, in Jerusalem’s Old City, on Tuesday. He describes himself as Catholic but also professes to have a deep connection with Judaism. ',
#      'copyright': 'Leo Correa/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-argentina-embassy-lmhq/06mideast-crisis-argentina-embassy-lmhq-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Javier Milei of Argentina at the Western Wall, in Jerusalem’s Old City, on Tuesday. He describes himself as Catholic but also professes to have a deep connection with Judaism. ',
#      'copyright': 'Leo Correa/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-argentina-embassy-lmhq/06mideast-crisis-argentina-embassy-lmhq-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Javier Milei of Argentina at the Western Wall, in Jerusalem’s Old City, on Tuesday. He describes himself as Catholic but also professes to have a deep connection with Judaism. ',
#      'copyright': 'Leo Correa/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06mideast-crisis-argentina-embassy-lmhq/06mideast-crisis-argentina-embassy-lmhq-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Javier Milei of Argentina at the Western Wall, in Jerusalem’s Old City, on Tuesday. He describes himself as Catholic but also professes to have a deep connection with Judaism. ',
#      'copyright': 'Leo Correa/Associated Press'}]},
#   {'slug_name': '06chile-president',
#    'section': 'World',
#    'subsection': 'Americas',
#    'title': 'Former Chilean President Sebastián Piñera Dies in Helicopter Crash',
#    'abstract': 'Mr. Piñera was a billionaire businessman who served two terms, leaving office in 2022.',
#    'uri': 'nyt://article/66060ec2-b65c-52ad-b92c-a511a4d8594a',
#    'url': 'https://www.nytimes.com/2024/02/06/world/americas/chile-sebastian-pinera-chile-dies.html',
#    'byline': 'By Jack Nicas and Pascale Bonnefoy',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-06T18:07:23-05:00',
#    'created_date': '2024-02-06T15:45:15-05:00',
#    'published_date': '2024-02-06T15:45:15-05:00',
#    'first_published_date': '2024-02-06T15:45:15-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Politics and Government',
#     'Aviation Accidents, Safety and Disasters',
#     'Income Inequality',
#     'Elections'],
#    'org_facet': [],
#    'per_facet': ['Pinera, Sebastian', 'Pinochet Ugarte, Augusto'],
#    'geo_facet': ['Chile'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06chile-president-vwmh/06chile-president-vwmh-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sebastián Piñera, at the time the president-elect of Chile, in Santiago in 2018.',
#      'copyright': 'Tomas Munita for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06chile-president-vwmh/06chile-president-vwmh-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sebastián Piñera, at the time the president-elect of Chile, in Santiago in 2018.',
#      'copyright': 'Tomas Munita for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06chile-president-vwmh/06chile-president-vwmh-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sebastián Piñera, at the time the president-elect of Chile, in Santiago in 2018.',
#      'copyright': 'Tomas Munita for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06chile-president-vwmh/06chile-president-vwmh-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sebastián Piñera, at the time the president-elect of Chile, in Santiago in 2018.',
#      'copyright': 'Tomas Munita for The New York Times'}]},
#   {'slug_name': '06UK-Royals-Privacy',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'King Pushed for Transparency on Diagnosis. He Raised Questions in the Process.',
#    'abstract': 'The king has let people know more about his health than other monarchs, but a decision to keep private the form of cancer he has is leading to speculation in lieu of facts.',
#    'uri': 'nyt://article/11ddb613-9008-5c75-82f6-82c93b3ae861',
#    'url': 'https://www.nytimes.com/2024/02/06/world/europe/king-charles-cancer-privacy.html',
#    'byline': 'By Mark Landler',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-06T15:41:57-05:00',
#    'created_date': '2024-02-06T15:15:28-05:00',
#    'published_date': '2024-02-06T15:15:28-05:00',
#    'first_published_date': '2024-02-06T15:15:28-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Cancer',
#     'Royal Families',
#     'International Relations',
#     'Privacy',
#     'News and News Media',
#     'Prostate Gland'],
#    'org_facet': ['National Health Service'],
#    'per_facet': ['Charles III, King of the United Kingdom',
#     'Camilla, Queen Consort of the United Kingdom',
#     'Catherine, Duchess of Cambridge'],
#    'geo_facet': ['Great Britain'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/06uk-royals-privacy-1-jfqt/07uk-royals-privacy-1-jfqt-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'King Charles and Queen Camilla in London on Tuesday.',
#      'copyright': 'Toby Melville/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/06uk-royals-privacy-1-jfqt/07uk-royals-privacy-1-jfqt-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'King Charles and Queen Camilla in London on Tuesday.',
#      'copyright': 'Toby Melville/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/06uk-royals-privacy-1-jfqt/07uk-royals-privacy-1-jfqt-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'King Charles and Queen Camilla in London on Tuesday.',
#      'copyright': 'Toby Melville/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2024/02/07/multimedia/06uk-royals-privacy-1-jfqt/07uk-royals-privacy-1-jfqt-articleInline.jpg',
#      'format': 'Normal',
#      'height': 126,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'King Charles and Queen Camilla in London on Tuesday.',
#      'copyright': 'Toby Melville/Reuters'}]},
#   {'slug_name': '06putin-tucker-carlson',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'Tucker Carlson Has Interviewed Putin, Kremlin Says',
#    'abstract': 'Moscow did not say when the interview would run. It is Mr. Putin’s first formal interview with Western news media since the start of his full-scale invasion of Ukraine.',
#    'uri': 'nyt://article/da486a57-a787-5211-b5f7-b0b3159245e3',
#    'url': 'https://www.nytimes.com/2024/02/06/world/europe/tucker-carlson-putin-interview.html',
#    'byline': 'By Anton Troianovski, Jim Rutenberg and Paul Sonne',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2024-02-07T06:06:23-05:00',
#    'created_date': '2024-02-06T14:43:42-05:00',
#    'published_date': '2024-02-06T14:43:42-05:00',
#    'first_published_date': '2024-02-06T14:43:42-05:00',
#    'material_type_facet': 'News',
#    'kicker': '',
#    'subheadline': '',
#    'des_facet': ['Politics and Government',
#     'United States International Relations',
#     'News and News Media',
#     'Russian Invasion of Ukraine (2022)'],
#    'org_facet': ['Fox News Channel'],
#    'per_facet': ['Carlson, Tucker', 'Putin, Vladimir V'],
#    'geo_facet': ['Moscow (Russia)'],
#    'related_urls': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06putin-carlson-sub-fgcq/06putin-carlson-sub-fgcq-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Tucker Carlson last year. An interview comes at a critical time for the war in Ukraine, with American aid to Kyiv stalled in Congress. ',
#      'copyright': 'Saul Martinez for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06putin-carlson-sub-fgcq/06putin-carlson-sub-fgcq-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Tucker Carlson last year. An interview comes at a critical time for the war in Ukraine, with American aid to Kyiv stalled in Congress. ',
#      'copyright': 'Saul Martinez for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06putin-carlson-sub-fgcq/06putin-carlson-sub-fgcq-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Tucker Carlson last year. An interview comes at a critical time for the war in Ukraine, with American aid to Kyiv stalled in Congress. ',
#      'copyright': 'Saul Martinez for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/02/06/multimedia/06putin-carlson-sub-fgcq/06putin-carlson-sub-fgcq-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Tucker Carlson last year. An interview comes at a critical time for the war in Ukraine, with American aid to Kyiv stalled in Congress. ',
#      'copyright': 'Saul Martinez for The New York Times'}]}]}

# %% [markdown]
# Let's take a look at the whole dictionary at once (well, only the titles and URLs)

# %%
print("There are %d different news retrieved"%len(result['results']))

for res in result['results']:
    print("Title: %s, Source: %s"%(res['title'], res['url']))
# Out:
# There are 20 different news retrieved
# Title: A key point of contention is whether a cease-fire would be permanent., Source: https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/a-key-point-of-contention-is-whether-a-cease-fire-would-be-permanent
# Title: Hungary and E.U. Lock Horns, This Time Over Foreign-Interference Law, Source: https://www.nytimes.com/2024/02/07/world/europe/hungary-eu-sovereignty-law.html
# Title: Macron condemns ‘largest antisemitic massacre of our century’ at an Oct. 7 tribute to French citizens who died in the assault., Source: https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/macron-condemns-largest-antisemitic-massacre-of-our-century-at-an-oct-7-tribute-to-french-citizens-who-died-in-the-assault
# Title: Election Office Blasts in Pakistan Kill at Least 22 a Day Before Vote, Source: https://www.nytimes.com/2024/02/07/world/asia/pakistan-elections-attacks.html
# Title: Blinken meets with Netanyahu as he tries to further cease-fire negotiations., Source: https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/blinken-meets-with-netanyahu-as-he-tries-to-further-cease-fire-negotiations
# Title: Sweden Closes Investigation Into Nord Stream Pipeline Blasts, Source: https://www.nytimes.com/2024/02/07/world/europe/sweden-nord-stream-pipeline.html
# Title: Terrorized by Gangs, Ecuador Embraces the Hard-Line ‘Noboa Way’, Source: https://www.nytimes.com/2024/02/07/world/americas/ecuador-gang-violence-noboa.html
# Title: It Was Once Pakistan’s Military Stronghold. Now Even It Has Had Enough., Source: https://www.nytimes.com/2024/02/07/world/asia/pakistan-election.html
# Title: Russian Strikes Hit Ukrainian Cities at a Tense Time for Kyiv, Source: https://www.nytimes.com/2024/02/07/world/europe/russia-ukraine-war-attack.html
# Title: Giorgia Meloni Solidifies Her Credentials in Europe, Source: https://www.nytimes.com/2024/02/07/world/europe/italy-meloni-orban-ukraine-funding.html
# Title: Playing Soccer in Abidjan? Get Yourself a Pair of Lêkê., Source: https://www.nytimes.com/2024/02/07/world/africa/ivory-coast-leke-africa-cup-of-nations.html
# Title: Iraq Hosts Both U.S. and Iranian-Backed Forces. It’s Getting Tense., Source: https://www.nytimes.com/2024/02/07/world/middleeast/iraq-iran-us-strikes.html
# Title: Hamas Gives ‘Positive’ Reply to Gaza Truce Plan, but Odds Remain Murky, Source: https://www.nytimes.com/2024/02/06/world/middleeast/hamas-israel-truce-hostage-negotiations.html
# Title: Biden criticizes Republicans for blocking an immigration bill containing aid for Israel and Gaza., Source: https://www.nytimes.com/live/2024/02/07/world/israel-hamas-war-gaza-news/biden-israel-aid-bill
# Title: Blinken Says ‘Agreement Is Possible’ With Hamas on a Hostage Deal, Source: https://www.nytimes.com/video/world/middleeast/100000009300985/blinken-israel-hamas-hostages.html
# Title: Wednesday Briefing: A Legal Blow to Trump, Source: https://www.nytimes.com/2024/02/06/world/asia/trump-case-israel-hostages-charles-asia.html
# Title: Arriving in Israel, Argentina’s new president promises to move his country’s embassy to Jerusalem., Source: https://www.nytimes.com/live/2024/02/06/world/israel-hamas-war-gaza-news/arriving-in-israel-argentinas-new-president-promises-to-move-his-countrys-embassy-to-jerusalem
# Title: Former Chilean President Sebastián Piñera Dies in Helicopter Crash, Source: https://www.nytimes.com/2024/02/06/world/americas/chile-sebastian-pinera-chile-dies.html
# Title: King Pushed for Transparency on Diagnosis. He Raised Questions in the Process., Source: https://www.nytimes.com/2024/02/06/world/europe/king-charles-cancer-privacy.html
# Title: Tucker Carlson Has Interviewed Putin, Kremlin Says, Source: https://www.nytimes.com/2024/02/06/world/europe/tucker-carlson-putin-interview.html

# %% [markdown]
# #### 1.5. Exercise: NYT top stories from last 30 days...
#
# It is now time for your to build your own REST API GET call. We want you to get the list of top stories from the last 30 days.
#
# First, you’ll have to examine the NYT documentation to find where the Most Popular API is (do you have it enabled?):  https://developer.nytimes.com/apis
#
# Then you'll have to understand how to really call it. What is the URL? What are the parameters?

# %% [markdown]
# #### 1.6. Exercise: NYT Most Popular

# %% [markdown]
# The NYT API allows us to access which stories got the most buzz. For example, do you want to show the most viewed articles in the last 7 days?

# %%
# Out:
# 200

# %% [markdown]
# ### 2. Combining services from different APIs. POST requests with the Sentiment Analysis API
#
# As you'll quickly find out, there are thousands of APIs available online, and even aggregators of such APIs. An example is http://rapidapi.com. Got there and create your account
#
# Feel free to browse the "API Hub", you may find services that you really like and can use later in your project! :-)

# %% [markdown]
# What we want to do now is to use another API, the Text Sentiment API (https://rapidapi.com/fyhao/api/text-sentiment-analysis-method/ is paid versus https://rapidapi.com/apininjas/api/sentiment-by-api-ninjas is free), to do a simple analysis on the comments we obtained from the NYT website.

# %% [markdown]
# #### 2.1. The anatomy of a POST request

# %% [markdown]
# The GET and POST are two different types of HTTP requests. GET is used for reading something without changing it, while POST is used for uploading data, i.e. changing something. For example, the NYT API only allowes for GET calls, since it provides news. But if it allowed us to send comments for example, it would have to be through the POST calls. The two sentiment APIs work differently and this reflect different design choices when they created the APIs. One works through a GET request while the other through a POST request.

# %% [markdown]
# In our case, the Text Sentiment API expects us to upload our text through a POST request called analyse.

# %% [markdown]
# ##### 2.2. Example 2: A POST request to Text Sentiment

# %% [markdown]
# Take a look below, at the different components of the call.

# %%
url = "https://text-sentiment.p.rapidapi.com/analyze"

payload = "text=I am so happy today... hmm, no, I'm actually quite sad... wait!"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'x-rapidapi-host': "text-sentiment.p.rapidapi.com",
    'x-rapidapi-key': "API-KEY"
    }
response = requests.request("POST", url, data=payload, headers=headers).json()

# %%
url = "https://sentiment-by-api-ninjas.p.rapidapi.com/v1/sentiment"

querystring = {"text":"It's a wonderful day!"}

headers = {
	"x-rapidapi-key": "API-KEY",
	"x-rapidapi-host": "sentiment-by-api-ninjas.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'score': 0.613, 'text': "It's a wonderful day!", 'sentiment': 'POSITIVE'}

# %%
response
# Out:
# {'score': 0.399,
#  'text': "text=I am so happy today... hmm, no, I'm actually quite sad... wait!",
#  'sentiment': 'WEAK_POSITIVE'}

# %% [markdown]
# #### 2.2. Assinging sentiment to the NYT stories
#
# Make a function called "get_sentiment", that receives a comment in text, and returns a sentiment value. If the value is 100, it should be the most positive sentiment. If it is 0, it is the most negative sentiment.

# %%
def get_sentiment(comment):
    url = "https://text-sentiment.p.rapidapi.com/analyze"

    payload = "text="+comment
    headers = {
        'content-type': "application/x-www-form-urlencoded",
        'x-rapidapi-host': "text-sentiment.p.rapidapi.com",
        'x-rapidapi-key': "API-KEY"
        }
    try:
        response = requests.request("POST", url, data=payload, headers=headers).json()
        sentiment=(response['pos']+response['mid']*.5+response['neg']*0)/(response['pos']+response['mid']+response['neg'])
    except:
        sentiment=.5
    
    return sentiment*100

# %%
def get_sentiment(comment):
    url = "https://sentiment-by-api-ninjas.p.rapidapi.com/v1/sentiment"

    headers = {
        'x-rapidapi-key': "API-KEY",
        'x-rapidapi-host': "sentiment-by-api-ninjas.p.rapidapi.com"
        }
    try:
        response = requests.get(url, headers=headers, params={'text': comment}).json()
        
        sentiment = response['score']
            
    except:
        sentiment=.5

    return sentiment*100

# %% [markdown]
# Can you now go through the same set of NYT most popular stories (most emails) from above (or something else of your choice...), and print the sentiment associated to each one? Also, for those most polarized (i.e. either 0 or 100), can you print them too?

# %%
# Out:
# 200

# %%
# Out:
# Comment: 1, author: By Patricia Leigh Brown, length: 153, title: It’s 50 Degrees in Minneapolis. Goodbye, Ice Shanties., sentiment:75
# Comment: 2, author: By Lindsay Zoladz, length: 106, title: Tracy Chapman and Luke Combs Gave America a Rare Gift: Harmony, sentiment:50
# Comment: 3, author: By Emily Anthes, length: 98, title: The Dogs That Live Longest, by a Nose, sentiment:100
# Polarized!
# Small dogs with prominent noses live longer than bigger, flat-faced canines, a new study suggests.
# Comment: 4, author: By David Marchese, length: 111, title: A Leading Memory Researcher Explains How to Make Precious Moments Last, sentiment:50
# Comment: 5, author: By Paula Span, length: 147, title: When a Spouse Goes to the Nursing Home, sentiment:50
# Comment: 6, author: By Kevin Roose, length: 119, title: Can This A.I.-Powered Search Engine Replace Google? It Has for Me., sentiment:50
# Comment: 7, author: By Knvul Sheikh, length: 76, title: How Long Does It Take to Get Fit Again?, sentiment:50
# Comment: 8, author: By Christina Caron, length: 168, title: Therapists Trade the Couch for the Great Outdoors, sentiment:100
# Polarized!
# Mental health practitioners are hiking, camping and braving the elements with their clients — all in an effort to help them connect with the Earth, and with themselves.
# Comment: 9, author: By Eric Klinenberg, length: 93, title: We Were Wrong About What Happened to America in 2020, sentiment:0
# Polarized!
# The answer, only now coming into view, explains why that awful year still has us in its grip.
# Comment: 10, author: By Cara Buckley, length: 134, title: Could a Giant Parasol in Outer Space Help Solve the Climate Crisis?, sentiment:75
# Comment: 11, author: By Alan Feuer and Charlie Savage, length: 193, title: Federal Appeals Court Rejects Trump’s Claim of Absolute Immunity, sentiment:0
# Polarized!
# The ruling answered a question that an appeals court had never addressed: Can former presidents escape being held accountable by the criminal justice system for things they did while in office?
# Comment: 12, author: By Elizabeth Williamson, length: 172, title: Cast as Criminals, America’s Librarians Rally to Their Own Defense, sentiment:50
# Comment: 13, author: By Liat Atzili, length: 71, title: Choosing Rebirth Over Revenge After My Release From Gaza, sentiment:50
# Comment: 14, author: By Melena Ryzik, length: 151, title: Susie Essman, the Scene-Stealer Who Makes Larry David Lose It, sentiment:50
# Comment: 15, author: By The New York Times, length: 164, title: These Tips Will Help You Turn Out Perfect Stovetop Rice Every Time, sentiment:50
# Comment: 16, author: By Emily Bazelon, length: 98, title: The Road to 1948, and the Roots of a Perpetual Conflict, sentiment:0
# Polarized!
# How the decisions that led to the founding of Israel have brought unending conflict to the region.
# Comment: 17, author: By Thomas L. Friedman, length: 137, title: A Biden Doctrine for the Middle East Is Forming. And It’s Big., sentiment:50
# Comment: 18, author: By Jonathan Weisman, length: 179, title: Taylor Swift, Travis Kelce and a MAGA Meltdown, sentiment:100
# Polarized!
# The fulminations surrounding the world’s biggest pop icon — and girlfriend of Chiefs tight end Travis Kelce — reached the stratosphere after Kansas City made it to the Super Bowl.
# Comment: 19, author: By Kashmir Hill, length: 183, title: A Practical Guide to Quitting Your Smartphone, sentiment:100
# Polarized!
# Readers who have taken the plunge said it had improved their lives, marriages and mental health, and offered advice to those going without their smartphones for “Flip Phone February.”
# Comment: 20, author: By Adam Shatz, length: 110, title: The World Has Caught Up to Frantz Fanon, sentiment:0
# Polarized!
# The shock of the new, in political life, often sends us back to the past in search of an intellectual compass.

# %% [markdown]
# #### 2.3. So many other things to do!...

# %% [markdown]
# The idea with this notebook was to give you access to this magnificent Web Mining tool that are the HTTP GET/POST API services. Now, it's your turn to explore. Some ideas (that may require you to register for further services):
# - Further use other text anaysis tools (e.g. Google Translate, GrammarBot, TextToImage...)
# - Extract the users from the NYT Community API and create ther influencer's graph
# - Inspect other APIs you may like (e.g. financial news, stockmarket, weather, enviroment, transport, ...)
