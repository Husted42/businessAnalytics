# %% [markdown]
# # Wedding planner

# %%
start_time=time_ns()
#*************************************************************************
# WeddingPlanner Assignment, "Mathematical Programming Modelling" (42112)
# utilizing Hamming-distance heurisitc optimization
#************************************************************************
# Intro definitions
using JuMP
using HiGHS
#using Gurobi
#************************************************************************

let
    #************************************************************************
    # PARAMETERS
    # Set: Guests, g,g1,g2
    # Set: Tables, t
    # DATA: SharedInterests[g1,g2]: 2-dim Guests*Guests: No of shared interests
    # DATA: Couple[g1,g2]: 2-dim Guests*Guests: 1 if two guests are partners, else 0 (symmetric)
    # DATA: Age[g]: 1-dim, Guests: Age measured in years
    # DATA: Male[g]: 1-dim, Guests: 1 if guest Male, 0 otherwise
    # DATA: Female[g]: 1-dim, Guests: 1 if guest Female, 0 otherwise
    # DATA: Know[g1,g2]: 2-dim Guests*Guests: 1 if two guests know each other (symmetric)
    time_limit=120
    K_initial=5 #"Neighbourhood size"
	K=K_initial 
    include("Data/WeddingData74.jl") # path to data
    G=length(Guests)
    T=length(Tables)
    TableCap=ceil(G/T)
    println("Runing Hamming-Distance-Heuristic on the WeddingPlanner with "*
			"$(G) guests, $(T) tables with capacity $(TableCap)\n")
    #************************************************************************
    
    #************************************************************************
    # Model
    wp =Model(HiGHS.Optimizer)
    #wp =Model(Gurobi.Optimizer)
    set_silent(wp) #To not get print from solver
    #Set timelimit pr MP solve to less than full timelimit
    set_time_limit_sec(wp, time_limit/2) 

    # 1 if guest g is sitting at table T
    @variable(wp, x[g=1:G,t=1:T], Bin)
	
	# Slack, if guest is NOT seated anywhere:
    @variable(wp, slack[g=1:G], Bin)

    # 1 if guest g1 and guest g2 are both sitting at table T
    @variable(wp, 0 <= y[g1=1:G,g2=1:G,t=1:T] <= ( g1 < g2 ? 1 : 0) ) 
    
    # Sum of different objectives
    @objective(wp, Max,
               # maximize total shared interests
               sum( SharedInterests[g1,g2]*y[g1,g2,t]
                    for t=1:T, g1=1:G, g2=1:G if g1<g2)
               
               # penalty of not planning all guests
               - sum( G*slack[g] for g=1:G) )                   
    
    # all guests have to sit at a table or have slack variable =1
    @constraint(wp, [g=1:G],
                slack[g] + sum( x[g,t] for t=1:T) == 1)
    
    # dont exceed the number of persons at a table
    @constraint(wp, [t=1:T],
                sum( x[g,t] for g=1:G) <= TableCap)
    
    # couples should sit at the same table
    @constraint(wp, [g1=1:G,g2=1:G,t=1:T; Couple[g1,g2]==1],
                x[g1,t] == x[g2,t])
    
    # limit y, can only become 1 if g1 is at the table t
    @constraint(wp, [g1=1:G,g2=1:G,t=1:T; g1<g2],
                y[g1,g2,t]  <= x[g1,t])
    
    # limit y, can only become 1 if g2 is (also) at the table t
    @constraint(wp, [g1=1:G,g2=1:G,t=1:T; g1<g2],
                y[g1,g2,t]  <= x[g2,t])
    #************************************************************************

    #************************************************************************
    
	#Function to add constraint that forces new solution and solves model again:
    function AddKConstraintAndOptimize(xVal,K)
        
        @constraint(wp, Kconstraint,
                    sum( x[g,t] for g=1:G,t=1:T if xVal[g,t]==0) +
                        sum( (1-x[g,t]) for g=1:G,t=1:T if xVal[g,t]==1)
                    <= K)
        optimize!(wp)
		
		#Extract infromation on the new solution:
        xVal=round.(Int,value.(x))
        slackVal=round.(Int,value.(slack))
        curObj=round(Int64,objective_value(wp))
		
		#Remove the newly added constraint from the model after use:
        delete(wp, Kconstraint)
        unregister(wp, :Kconstraint)
		
        return (curObj,xVal,slackVal)
    end

    println("Starting Hamming Distance Heuristic")
    xVal=zeros(Int8,G,T) #Start with empty solution, NO guests are seated

    it=1
    curObj=-1
    oldObj=-1
    
    while (time_ns()-start_time)/1.0e9<time_limit
        (curObj,xVal,slackVal)=AddKConstraintAndOptimize(xVal,K)
        this_time=(time_ns()-start_time)/1.0e9
        println("It: $(it) Time: $(round(this_time,digits=1)) K: $(K) "*
				"CurObj: $(curObj) Slack: $(sum(slackVal[g] for g=1:G))")
        if curObj<=oldObj # comparison for maximization problems
            K=K+1 #If no improvement, increase neighbourhood.
        else
            K=K_initial #If there IS improvement then search with small neighbourhood for as long as possible
        end
        oldObj=curObj
        it+=1
    end
    #************************************************************************
    
    #************************************************************************
    println("Successfull end of $(PROGRAM_FILE)")
    #************************************************************************
end
# Out:
# Runing Hamming-Distance-Heuristic on the WeddingPlanner with 74 guests, 9 tables with capacity 9.0
#
# Starting Hamming Distance Heuristic
# It: 1 Time: 2.7 K: 1 CurObj: -5402 Slack: 73
# It: 2 Time: 9.6 K: 2 CurObj: -5245 Slack: 71
# It: 3 Time: 9.7 K: 1 CurObj: -5169 Slack: 70
# It: 4 Time: 9.8 K: 1 CurObj: -5093 Slack: 69
# It: 5 Time: 9.9 K: 1 CurObj: -5018 Slack: 68
# It: 6 Time: 10.0 K: 1 CurObj: -4941 Slack: 67
# It: 7 Time: 10.1 K: 1 CurObj: -4863 Slack: 66
# It: 8 Time: 10.1 K: 1 CurObj: -4784 Slack: 65
# It: 9 Time: 10.2 K: 1 CurObj: -4710 Slack: 64
# It: 10 Time: 10.3 K: 1 CurObj: -4635 Slack: 63
# It: 11 Time: 10.4 K: 1 CurObj: -4559 Slack: 62
# It: 12 Time: 10.5 K: 1 CurObj: -4481 Slack: 61
# It: 13 Time: 10.6 K: 1 CurObj: -4403 Slack: 60
# It: 14 Time: 10.6 K: 1 CurObj: -4323 Slack: 59
# It: 15 Time: 10.7 K: 1 CurObj: -4248 Slack: 58
# It: 16 Time: 10.8 K: 1 CurObj: -4172 Slack: 57
# It: 17 Time: 10.9 K: 1 CurObj: -4097 Slack: 56
# It: 18 Time: 10.9 K: 1 CurObj: -4023 Slack: 55
# It: 19 Time: 11.0 K: 1 CurObj: -3948 Slack: 54
# It: 20 Time: 11.0 K: 1 CurObj: -3873 Slack: 53
# It: 21 Time: 11.2 K: 1 CurObj: -3799 Slack: 52
# It: 22 Time: 11.3 K: 1 CurObj: -3725 Slack: 51
# It: 23 Time: 11.3 K: 1 CurObj: -3651 Slack: 50
# It: 24 Time: 11.4 K: 1 CurObj: -3651 Slack: 50
# It: 25 Time: 14.8 K: 2 CurObj: -3495 Slack: 48
# It: 26 Time: 14.9 K: 1 CurObj: -3495 Slack: 48
# It: 27 Time: 17.2 K: 2 CurObj: -3343 Slack: 46
# It: 28 Time: 17.2 K: 1 CurObj: -3343 Slack: 46
# It: 29 Time: 19.5 K: 2 CurObj: -3186 Slack: 44
# It: 30 Time: 19.6 K: 1 CurObj: -3186 Slack: 44
# It: 31 Time: 20.8 K: 2 CurObj: -3016 Slack: 42
# It: 32 Time: 20.9 K: 1 CurObj: -3016 Slack: 42
# It: 33 Time: 21.9 K: 2 CurObj: -2846 Slack: 40
# It: 34 Time: 22.0 K: 1 CurObj: -2846 Slack: 40
# It: 35 Time: 22.9 K: 2 CurObj: -2694 Slack: 38
# It: 36 Time: 23.0 K: 1 CurObj: -2694 Slack: 38
# It: 37 Time: 23.9 K: 2 CurObj: -2536 Slack: 36
# It: 38 Time: 24.0 K: 1 CurObj: -2536 Slack: 36
# It: 39 Time: 24.9 K: 2 CurObj: -2373 Slack: 34
# It: 40 Time: 24.9 K: 1 CurObj: -2373 Slack: 34
# It: 41 Time: 25.8 K: 2 CurObj: -2210 Slack: 32
# It: 42 Time: 25.8 K: 1 CurObj: -2210 Slack: 32
# It: 43 Time: 26.4 K: 2 CurObj: -2059 Slack: 30
# It: 44 Time: 26.5 K: 1 CurObj: -2059 Slack: 30
# It: 45 Time: 27.0 K: 2 CurObj: -1904 Slack: 28
# It: 46 Time: 27.1 K: 1 CurObj: -1904 Slack: 28
# It: 47 Time: 27.6 K: 2 CurObj: -1740 Slack: 26
# It: 48 Time: 27.7 K: 1 CurObj: -1740 Slack: 26
# It: 49 Time: 28.2 K: 2 CurObj: -1575 Slack: 24
# It: 50 Time: 28.2 K: 1 CurObj: -1575 Slack: 24
# It: 51 Time: 28.6 K: 2 CurObj: -1424 Slack: 22
# It: 52 Time: 28.7 K: 1 CurObj: -1424 Slack: 22
# It: 53 Time: 29.0 K: 2 CurObj: -1269 Slack: 20
# It: 54 Time: 29.1 K: 1 CurObj: -1269 Slack: 20
# It: 55 Time: 29.5 K: 2 CurObj: -1117 Slack: 18
# It: 56 Time: 29.5 K: 1 CurObj: -1117 Slack: 18
# It: 57 Time: 29.9 K: 2 CurObj: -963 Slack: 16
# It: 58 Time: 30.0 K: 1 CurObj: -963 Slack: 16
# It: 59 Time: 30.3 K: 2 CurObj: -813 Slack: 14
# It: 60 Time: 30.4 K: 1 CurObj: -813 Slack: 14
# It: 61 Time: 30.8 K: 2 CurObj: -660 Slack: 12
# It: 62 Time: 30.8 K: 1 CurObj: -660 Slack: 12
# It: 63 Time: 31.2 K: 2 CurObj: -508 Slack: 10
# It: 64 Time: 31.2 K: 1 CurObj: -508 Slack: 10
# It: 65 Time: 31.6 K: 2 CurObj: -357 Slack: 8
# It: 66 Time: 31.6 K: 1 CurObj: -357 Slack: 8
# It: 67 Time: 32.0 K: 2 CurObj: -207 Slack: 6
# It: 68 Time: 32.1 K: 1 CurObj: -207 Slack: 6
# It: 69 Time: 32.4 K: 2 CurObj: -58 Slack: 4
# It: 70 Time: 32.5 K: 1 CurObj: -58 Slack: 4
# It: 71 Time: 32.8 K: 2 CurObj: 91 Slack: 2
# It: 72 Time: 32.9 K: 1 CurObj: 91 Slack: 2
# It: 73 Time: 33.2 K: 2 CurObj: 239 Slack: 0
# It: 74 Time: 33.3 K: 1 CurObj: 239 Slack: 0
# It: 75 Time: 33.7 K: 2 CurObj: 250 Slack: 0
# It: 76 Time: 33.7 K: 1 CurObj: 250 Slack: 0
# It: 77 Time: 34.1 K: 2 CurObj: 255 Slack: 0
# It: 78 Time: 34.1 K: 1 CurObj: 255 Slack: 0
# It: 79 Time: 34.5 K: 2 CurObj: 261 Slack: 0
# It: 80 Time: 34.5 K: 1 CurObj: 261 Slack: 0
# It: 81 Time: 34.8 K: 2 CurObj: 268 Slack: 0
# It: 82 Time: 34.9 K: 1 CurObj: 268 Slack: 0
# It: 83 Time: 35.2 K: 2 CurObj: 272 Slack: 0
# It: 84 Time: 35.2 K: 1 CurObj: 272 Slack: 0
# It: 85 Time: 35.5 K: 2 CurObj: 274 Slack: 0
# It: 86 Time: 35.5 K: 1 CurObj: 274 Slack: 0
# It: 87 Time: 35.8 K: 2 CurObj: 275 Slack: 0
# It: 88 Time: 35.8 K: 1 CurObj: 275 Slack: 0
# It: 89 Time: 36.1 K: 2 CurObj: 275 Slack: 0
# It: 90 Time: 36.4 K: 3 CurObj: 275 Slack: 0
# It: 91 Time: 36.8 K: 4 CurObj: 280 Slack: 0
# It: 92 Time: 36.9 K: 1 CurObj: 280 Slack: 0
# It: 93 Time: 37.1 K: 2 CurObj: 283 Slack: 0
# It: 94 Time: 37.2 K: 1 CurObj: 283 Slack: 0
# It: 95 Time: 37.4 K: 2 CurObj: 283 Slack: 0
# It: 96 Time: 37.7 K: 3 CurObj: 283 Slack: 0
# It: 97 Time: 38.3 K: 4 CurObj: 288 Slack: 0
# It: 98 Time: 38.4 K: 1 CurObj: 288 Slack: 0
# It: 99 Time: 38.6 K: 2 CurObj: 291 Slack: 0
# It: 100 Time: 38.7 K: 1 CurObj: 291 Slack: 0
# It: 101 Time: 38.9 K: 2 CurObj: 294 Slack: 0
# It: 102 Time: 39.0 K: 1 CurObj: 294 Slack: 0
# It: 103 Time: 39.3 K: 2 CurObj: 294 Slack: 0
# It: 104 Time: 39.6 K: 3 CurObj: 294 Slack: 0
# It: 105 Time: 40.3 K: 4 CurObj: 300 Slack: 0
# It: 106 Time: 40.4 K: 1 CurObj: 300 Slack: 0
# It: 107 Time: 40.6 K: 2 CurObj: 300 Slack: 0
# It: 108 Time: 40.9 K: 3 CurObj: 300 Slack: 0
# It: 109 Time: 41.7 K: 4 CurObj: 301 Slack: 0
# It: 110 Time: 41.7 K: 1 CurObj: 301 Slack: 0
# It: 111 Time: 42.0 K: 2 CurObj: 301 Slack: 0
# It: 112 Time: 42.3 K: 3 CurObj: 301 Slack: 0
# It: 113 Time: 42.7 K: 4 CurObj: 302 Slack: 0
# It: 114 Time: 42.8 K: 1 CurObj: 302 Slack: 0
# It: 115 Time: 43.0 K: 2 CurObj: 303 Slack: 0
# It: 116 Time: 43.1 K: 1 CurObj: 303 Slack: 0
# It: 117 Time: 43.4 K: 2 CurObj: 305 Slack: 0
# It: 118 Time: 43.5 K: 1 CurObj: 305 Slack: 0
# It: 119 Time: 43.7 K: 2 CurObj: 306 Slack: 0
# It: 120 Time: 43.8 K: 1 CurObj: 306 Slack: 0
# It: 121 Time: 44.1 K: 2 CurObj: 306 Slack: 0
# It: 122 Time: 44.4 K: 3 CurObj: 306 Slack: 0
# It: 123 Time: 45.4 K: 4 CurObj: 306 Slack: 0
# It: 124 Time: 47.6 K: 5 CurObj: 306 Slack: 0
# It: 125 Time: 63.3 K: 6 CurObj: 306 Slack: 0
# It: 126 Time: 85.5 K: 7 CurObj: 306 Slack: 0
# It: 127 Time: 145.5 K: 8 CurObj: 311 Slack: 0
# Successfull end of

# %% [markdown]
# k = 1 -> It: 127 Time: 145.5 K: 8 CurObj: 311 Slack: 0
#
# I assume that when we increasse k we will get a better solution, since we are allowed to change more variables
