# %%
import Pkg
Pkg.add("JuMP")
Pkg.add("HiGHS")

# %%
using JuMP, HiGHS

########## ---------- Models ---------- ##########
model = Model(HiGHS.Optimizer)
set_optimizer_attribute(model, "log_to_console", false)


########## ---------- Variables ---------- ##########


########## ---------- Objectives ---------- ##########


########## ---------- Constraints ---------- ##########



########## ---------- Optimize ---------- ##########
